# %%
#importing necessary libraries
import cv2
import tensorflow as tf
import os
import glob
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
imdir = "input1"

# %%
#prepare(file) allows us to use an image of any size, since it automatically resize it to the image size we defined in the first program.
def prepare(file):
    IMG_SIZE = 50
    img_array = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
#hconcat_resize_min() takes the image list as an argument and resizes the image to the maximum height in the list
#and concatenates them horizontally
def hconcat_resize_min(im_list, interpolation=cv2.INTER_CUBIC):
    h_max = max(im.shape[0] for im in im_list)
    im_list_resize = [cv2.resize(im, (int(im.shape[1] * h_max / im.shape[0]), h_max), interpolation=interpolation)
                      for im in im_list]
    return cv2.hconcat(im_list_resize)

# %%
model = tf.keras.models.load_model("CNN.model") # Loding pre-trained data trained at Harshit's machine
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model = tf.keras.models.load_model("CNN.model") # Loding pre-trained data trained at Harshit's machine
#
# File c:\Users\BK\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\BK\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\BK\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\legacy\save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at CNN.model

# %%
import numpy as np


filelist = glob.glob(os.path.join(imdir, '*.jpg')) #reading all the files in image directory

for i in range(len(filelist)):
    image = prepare(filelist[i]) #Single image that you want to predict
    prediction = model.predict([image]) #predicting if the image is part of multicharacter or not     
    prediction = prediction[0]
    im1 = cv2.imread(filelist[i])
    print(filelist[i])
    lists=["ஐ","ச","எ","ஒ","க","ழூ","ழு","ழ","ல","நு","நா","n2u4","ண","னு","","ந","ஒ","பூ","ப","ர","ரீ","ரு","ர","தி","த","ய"]
    classes=np.argmax(prediction)
    print(lists[classes])
     #if the image belongs to MultipartClass and is not the last image append it to next image
    
#     print(filelist[i])  #printing file path of all the images classified as MultipartCharacter
#     im2 = cv2.imread(filelist[i+1])
#     im_h_resize = hconcat_resize_min([im1, im2])
#     cv2.imwrite(outdir+"\\"+str(j)+".jpg", im_h_resize)
#     j=j+1
# Out:
# Class2-NonMultipartCharcaters\1.JPG
# க
# Class2-NonMultipartCharcaters\10.JPG
#
# Class2-NonMultipartCharcaters\100.JPG
# ஒ
# Class2-NonMultipartCharcaters\101.JPG
# ரீ
# Class2-NonMultipartCharcaters\102.JPG
# ப
# Class2-NonMultipartCharcaters\103.JPG
# n2u4
# Class2-NonMultipartCharcaters\104.JPG
# ரு
# Class2-NonMultipartCharcaters\105.JPG
# ச
# Class2-NonMultipartCharcaters\54.JPG
# ர
# Class2-NonMultipartCharcaters\55.JPG
# பூ
# Class2-NonMultipartCharcaters\56.JPG
# ஒ
# Class2-NonMultipartCharcaters\57.JPG
# ர
# Class2-NonMultipartCharcaters\58.JPG
# க
# Class2-NonMultipartCharcaters\59.JPG
# ஒ
# Class2-NonMultipartCharcaters\6.JPG
# ர
# Class2-NonMultipartCharcaters\60.JPG
# க
# Class2-NonMultipartCharcaters\61.JPG
# ய
# Class2-NonMultipartCharcaters\62.JPG
# ப
# Class2-NonMultipartCharcaters\63.JPG
# ஒ
# Class2-NonMultipartCharcaters\64.JPG
# ந
# Class2-NonMultipartCharcaters\65.JPG
# நா
# Class2-NonMultipartCharcaters\67.JPG
# ந
# Class2-NonMultipartCharcaters\68.JPG
# ந
# Class2-NonMultipartCharcaters\69.JPG
# ஐ
# Class2-NonMultipartCharcaters\7.JPG
# ஒ
# Class2-NonMultipartCharcaters\70.JPG
# ழூ
# Class2-NonMultipartCharcaters\71.JPG
# க
# Class2-NonMultipartCharcaters\72.JPG
# ழு
# Class2-NonMultipartCharcaters\73.JPG
#
# Class2-NonMultipartCharcaters\74.JPG
# ச
# Class2-NonMultipartCharcaters\75.JPG
# ர
# Class2-NonMultipartCharcaters\76.JPG
# க
# Class2-NonMultipartCharcaters\77.JPG
# தி
# Class2-NonMultipartCharcaters\78.JPG
# த
# Class2-NonMultipartCharcaters\79.JPG
# க
# Class2-NonMultipartCharcaters\8.JPG
#
# Class2-NonMultipartCharcaters\80.JPG
# தி
# Class2-NonMultipartCharcaters\81.JPG
# ரு
# Class2-NonMultipartCharcaters\82.JPG
# ர
# Class2-NonMultipartCharcaters\83.JPG
# பூ
# Class2-NonMultipartCharcaters\85.JPG
# னு
# Class2-NonMultipartCharcaters\86.JPG
# ரீ
# Class2-NonMultipartCharcaters\87.JPG
# ப
# Class2-NonMultipartCharcaters\88.JPG
# எ
# Class2-NonMultipartCharcaters\89.JPG
# ழ
# Class2-NonMultipartCharcaters\9.JPG
# ஒ
# Class2-NonMultipartCharcaters\90.JPG
# பூ
# Class2-NonMultipartCharcaters\91.JPG
# தி
# Class2-NonMultipartCharcaters\92.JPG
# ஒ
# Class2-NonMultipartCharcaters\93.JPG
# க
# Class2-NonMultipartCharcaters\94.JPG
# ஒ
# Class2-NonMultipartCharcaters\95.JPG
# ர
# Class2-NonMultipartCharcaters\96.JPG
# ண
# Class2-NonMultipartCharcaters\97.JPG
# தி
# Class2-NonMultipartCharcaters\98.JPG
# பூ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
image_path='24.jpg'
im = cv2.imread(image_path)
# im= prepare(image_path)
plt.imshow(im)

# %%
import numpy as np
im = cv2.imread(image_path)
im= prepare(image_path)
  #opencv reads image in BGR format to display in matplot lib we convert it to RGB
prediction = model.predict([im])
prediction=prediction[0]
# print(prediction)
lists=["ஐ","ச","எ","ஒ","க","ழூ","ழு","ழ","ல","நு","நா","n2u4","ண","னு","","ந","ஒ","பூ","ப","ர","ரீ","ரு","ர","தி","த","ய"]
# prediction.index(max(prediction))
classes=np.argmax(prediction)
print(lists[classes])
# Out:
# ர
